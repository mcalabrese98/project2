# %%
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
movie_data_path = Path("movie_data.csv")

movie_data_df = pd.read_csv(movie_data_path)

movie_data_df.head()
# Out:
#    Unnamed: 0  adult                     backdrop_path  belongs_to_collection  \
# 0           0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg                    NaN
# 1           1  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg                    NaN
# 2           2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                    NaN
# 3           3  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg                    NaN
# 4           4  False  /3sh2UA2Q2l7fihgoj1LhFFPTlIM.jpg                    NaN
#
#       budget genres    genres_0_name    genres_1_name    genres_2_name  \
# 0   78000000    NaN        Animation  Science Fiction           Family
# 1   80000000    NaN  Science Fiction           Horror              NaN
# 2   17500000    NaN           Horror            Drama  Science Fiction
# 3  200000000    NaN           Action           Comedy  Science Fiction
# 4  110000000    NaN           Action  Science Fiction        Adventure
#
#   genres_3_name  ... spoken_languages_8_name  spoken_languages_9_english_name  \
# 0           NaN  ...                     NaN                              NaN
# 1           NaN  ...                     NaN                              NaN
# 2           NaN  ...                     NaN                              NaN
# 3           NaN  ...                     NaN                              NaN
# 4           NaN  ...                     NaN                              NaN
#
#   spoken_languages_9_iso_639_1  spoken_languages_9_name    status  \
# 0                          NaN                      NaN  Released
# 1                          NaN                      NaN  Released
# 2                          NaN                      NaN  Released
# 3                          NaN                      NaN  Released
# 4                          NaN                      NaN  Released
#
#                                              tagline                  title  \
# 0                         Discover your true nature.         The Wild Robot
# 1                     In space, no one can hear you.         Alien: Romulus
# 2  If you follow the instructions, what could go ...          The Substance
# 3                                     Come together.   Deadpool & Wolverine
# 4                           'Til death do they part.  Venom: The Last Dance
#
#    video vote_average vote_count
# 0  False        8.700       1363
# 1  False        7.300       1829
# 2  False        7.300        829
# 3  False        7.713       4748
# 4  False        7.200         28
#
# [5 rows x 153 columns]

# %%
movie_data_train, movie_data_test = train_test_split(movie_data_df, test_size=0.2, random_state=42)

movie_data_train.to_csv("movie_data_train2.csv", index=False)
movie_data_test.to_csv("movie_data_test2.csv", index=False)
